# %%
# if run on colab
#!pip install torcheeg
#from google.colab import mount
#drive.mount('/content/drive', force_remount=True)

# %%
# if run on kaggle
# !pip install torcheeg
# Out:
# Collecting torcheeg
#   Downloading torcheeg-1.1.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.5/214.5 kB 3.8 MB/s eta 0:00:00
# done
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (4.66.1)
# Requirement already satisfied: numpy>=1.21.5 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (2.1.4)
# Collecting xlrd>=2.0.1 (from torcheeg)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.2.2)
# Collecting lmdb>=1.3.0 (from torcheeg)
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting einops>=0.4.1 (from torcheeg)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mne>=1.0.3 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.6.1)
# Collecting xmltodict>=0.13.0 (from torcheeg)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: networkx>=2.6.3 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (3.2.1)
# Requirement already satisfied: PyWavelets>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.5.0)
# Collecting spectrum>=0.8.1 (from torcheeg)
#   Downloading spectrum-0.8.1.tar.gz (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.8/230.8 kB 13.4 MB/s eta 0:00:00
# done
# Requirement already satisfied: torchmetrics>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (1.3.2)
# Collecting mne_connectivity>=0.4.0 (from torcheeg)
#   Downloading mne_connectivity-0.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pytorch-lightning>=1.9.5 in /opt/conda/lib/python3.10/site-packages (from torcheeg) (2.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (3.7.5)
# Requirement already satisfied: pooch>=1.5 in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (1.8.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (5.1.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (21.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from mne>=1.0.3->torcheeg) (0.3)
# Collecting netCDF4>=1.6.5 (from mne_connectivity>=0.4.0->torcheeg)
#   Downloading netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: xarray>=2023.11.0 in /opt/conda/lib/python3.10/site-packages (from mne_connectivity>=0.4.0->torcheeg) (2024.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->torcheeg) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->torcheeg) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->torcheeg) (2023.4)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning>=1.9.5->torcheeg) (2.1.2)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning>=1.9.5->torcheeg) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (2024.2.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning>=1.9.5->torcheeg) (4.9.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning>=1.9.5->torcheeg) (0.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.2->torcheeg) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.2->torcheeg) (3.2.0)
# Collecting easydev (from spectrum>=0.8.1->torcheeg)
#   Downloading easydev-0.13.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (3.9.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=1.9.5->torcheeg) (69.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne>=1.0.3->torcheeg) (3.1.1)
# Collecting cftime (from netCDF4>=1.6.5->mne_connectivity>=0.4.0->torcheeg)
#   Downloading cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from netCDF4>=1.6.5->mne_connectivity>=0.4.0->torcheeg) (2024.2.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne>=1.0.3->torcheeg) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne>=1.0.3->torcheeg) (2.31.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->torcheeg) (1.16.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->pytorch-lightning>=1.9.5->torcheeg) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->pytorch-lightning>=1.9.5->torcheeg) (1.12)
# Collecting packaging (from mne>=1.0.3->torcheeg)
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from easydev->spectrum>=0.8.1->torcheeg) (0.4.6)
# Requirement already satisfied: colorlog<7.0.0,>=6.8.2 in /opt/conda/lib/python3.10/site-packages (from easydev->spectrum>=0.8.1->torcheeg) (6.8.2)
# Requirement already satisfied: line-profiler<5.0.0,>=4.1.2 in /opt/conda/lib/python3.10/site-packages (from easydev->spectrum>=0.8.1->torcheeg) (4.1.2)
# Collecting pexpect<5.0.0,>=4.9.0 (from easydev->spectrum>=0.8.1->torcheeg)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->mne>=1.0.3->torcheeg) (2.1.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.9.5->torcheeg) (4.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect<5.0.0,>=4.9.0->easydev->spectrum>=0.8.1->torcheeg) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0.3->torcheeg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0.3->torcheeg) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0.3->torcheeg) (1.26.18)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->pytorch-lightning>=1.9.5->torcheeg) (1.3.0)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.3 MB/s eta 0:00:00
# Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 16.0 MB/s eta 0:00:00
# Downloading mne_connectivity-0.6.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 7.1 MB/s eta 0:00:00
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.0 MB/s eta 0:00:00
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 61.4 MB/s eta 0:00:00
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 3.0 MB/s eta 0:00:00
# Downloading easydev-0.13.2-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.1 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.0 MB/s eta 0:00:00
# Downloading cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.5 MB/s eta 0:00:00
# Building wheels for collected packages: torcheeg, spectrum
# done
#   Created wheel for torcheeg: filename=torcheeg-1.1.2-py3-none-any.whl size=414907 sha256=8ed22023ffabc19d453c0798715996a80b8f80473ae49946f94bcf2fbc504d72
#   Stored in directory: /root/.cache/pip/wheels/4b/9d/45/dc74737527e063f030217eda1f25791f98f06cc0bc6f013e4c
# done
#   Created wheel for spectrum: filename=spectrum-0.8.1-cp310-cp310-linux_x86_64.whl size=227335 sha256=6869e68dd3baede7c0ea665d9a03bc48aac49cbc2a4c7d9f810d70898078de22
#   Stored in directory: /root/.cache/pip/wheels/e7/5a/09/ffc6afdf8a5a6f58e9851292108df32bb11374e11b8705cabd
# Successfully built torcheeg spectrum
# Installing collected packages: lmdb, xmltodict, xlrd, pexpect, packaging, einops, cftime, netCDF4, easydev, spectrum, mne_connectivity, torcheeg
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.8.0
#     Uninstalling pexpect-4.8.0:
#       Successfully uninstalled pexpect-4.8.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.0 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed cftime-1.6.3 easydev-0.13.2 einops-0.8.0 lmdb-1.4.1 mne_connectivity-0.6.0 netCDF4-1.6.5 packaging-24.0 pexpect-4.9.0 spectrum-0.8.1 torcheeg-1.1.2 xlrd-2.0.1 xmltodict-0.13.0

# %%
import torcheeg
from torcheeg import transforms
from torcheeg.datasets import BCICIV2aDataset
from torcheeg.model_selection import KFoldGroupbyTrial
from torch.utils.data import DataLoader
from torcheeg.models import ATCNet, EEGNet
import torch

from torcheeg.trainers import ClassifierTrainer

import pytorch_lightning as pl

# %%
# if run on kaggle
root_data_path = '/kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat'

# if run on colab
# root_data_path = './BCICIV-2a-mat/'

# %%
# if run on local machine
# root_data_path = './BCICIV-2a-mat/'

# %%
dataset = BCICIV2aDataset(
    root_path=root_data_path,
    io_path=f'./examples_pipeline/bciciv-2a',
    skip_trial_with_artifacts=True,
    # offline_transform=transforms.Compose([
    #     transforms.To2d(),
    # ]),
    online_transform=transforms.Compose([
        transforms.To2d(),
        transforms.MinMaxNormalize(),
        transforms.ToTensor(),
    ]),
    label_transform=transforms.Compose([
        transforms.Select('label'),
        transforms.Lambda(lambda x: x - 1)
    ]),
    chunk_size=7*250,
    num_worker=2
)
# Out:
# [2024-05-17 05:12:40] INFO (torcheeg/MainThread) 🔍 | Processing EEG data. Processed EEG data has been cached to ./examples_pipeline/bciciv-2a.
# [2024-05-17 05:12:40] INFO (torcheeg/MainThread) ⏳ | Monitoring the detailed processing of a record for debugging. The processing of other records will only be reported in percentage to keep it clean.
# [PROCESS]:   0%|          | 0/18 [00:00<?, ?it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 0it [00:00, ?it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 1it [00:01,  1.05s/it]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 14it [00:01, 16.39it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 24it [00:01, 28.29it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 33it [00:01, 38.61it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 42it [00:01, 48.33it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 51it [00:01, 57.15it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 60it [00:01, 64.74it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 69it [00:01, 70.52it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 78it [00:01, 75.44it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 87it [00:01, 79.31it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 96it [00:02, 81.34it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 105it [00:02, 83.45it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 114it [00:02, 85.11it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 123it [00:02, 86.48it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 133it [00:02, 87.25it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 142it [00:02, 87.78it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 151it [00:02, 87.06it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 160it [00:02, 87.29it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 169it [00:02, 87.07it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 178it [00:03, 87.45it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 187it [00:03, 86.72it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 196it [00:03, 87.10it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 205it [00:03, 87.11it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 214it [00:03, 86.53it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 224it [00:03, 88.43it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 233it [00:03, 88.55it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 242it [00:03, 87.71it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 251it [00:03, 87.50it/s]
# [RECORD /kaggle/input/bci-competition-iv-dataset-2a-in-mat-format/BCICIV-2a-mat/A04T.mat]: 260it [00:03, 86.40it/s]
# [PROCESS]: 100%|██████████| 18/18 [00:38<00:00,  2.11s/it]
# [2024-05-17 05:13:22] INFO (torcheeg/MainThread) ✅ | All processed EEG data has been cached to ./examples_pipeline/bciciv-2a.
# [2024-05-17 05:13:22] INFO (torcheeg/MainThread) 😊 | Please set io_path to ./examples_pipeline/bciciv-2a for the next run, to directly read from the cache if you wish to skip the data processing step.

# %%
print("Dataset's info: ")
print(dataset.info)
# Out:
# Dataset's info:
#       start_at  end_at   clip_id subject_id  trial_id session subject  run  \
# 0          251    2001    A04T_0        A04         0       T     A04    1
# 1         2254    4004    A04T_1        A04         1       T     A04    1
# 2         4172    5922    A04T_2        A04         2       T     A04    1
# 3         6124    7874    A04T_3        A04         3       T     A04    1
# 4         8132    9882    A04T_4        A04         4       T     A04    1
# ...        ...     ...       ...        ...       ...     ...     ...  ...
# 4691     86751   88501  A04E_223        A04        43       E     A04    8
# 4692     88657   90407  A04E_224        A04        44       E     A04    8
# 4693     90585   92335  A04E_225        A04        45       E     A04    8
# 4694     92699   94449  A04E_226        A04        46       E     A04    8
# 4695     94758   96508  A04E_227        A04        47       E     A04    8
#
#       label  _record_id
# 0         4   _record_0
# 1         4   _record_0
# 2         1   _record_0
# 3         4   _record_0
# 4         1   _record_0
# ...     ...         ...
# 4691      1  _record_17
# 4692      3  _record_17
# 4693      1  _record_17
# 4694      2  _record_17
# 4695      1  _record_17
#
# [4696 rows x 10 columns]

# %%
k_fold = KFoldGroupbyTrial(
    n_splits=4,
    split_path='./examples_pipeline/split',
    shuffle=True,
    random_state=44
)

# %%
DEVICE = 'gpu' if torch.cuda.is_available() else 'cpu'

for i, (train_dataset, val_dataset) in enumerate(k_fold.split(dataset)):
    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=64,
        shuffle=True,
        num_workers=4
    )
    val_loader = DataLoader(
        dataset=val_dataset,
        batch_size=64,
        shuffle=False,
        num_workers=4
    )
    
    model = ATCNet(
        num_classes=4,
        num_electrodes=22,
        chunk_size=7*250,
    )
    
    trainer = ClassifierTrainer(
        model=model,
        num_classes=4,
        lr=1e-4,
        weight_decay=1e-4,
        accelerator=DEVICE
    )

    trainer.fit(
        train_loader,
        val_loader, 
        max_epochs=50,
        default_root_dir=f'./examples_pipeline/atcnet_preprocessed_model/{i}',
        callbacks=[pl.callbacks.ModelCheckpoint(save_last=True)],
        enable_progress_bar=True,
        enable_model_summary=True,
        limit_val_batches=0.0
    )

    score = trainer.test(
        val_loader,
        enable_progress_bar=True,
        enable_model_summary=True
    )[0]
    print(f"Fold {i} test accuracy: {score['test_accuracy']: .4f}")
# Out:
# [2024-05-17 05:13:23] INFO (torcheeg/MainThread) 📊 | Create the split of train and test set.
# [2024-05-17 05:13:23] INFO (torcheeg/MainThread) 😊 | Please set split_path to ./examples_pipeline/split for the next run, if you want to use the same setting for the experiment.
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/Convolution.cpp:1008.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-05-17 05:13:31.856445: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 05:13:31.856546: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 05:13:31.990748: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training: |          | 0/? [00:00<?, ?it/s]
# [2024-05-17 05:13:47] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.389 train_accuracy: 0.250
#
# [2024-05-17 05:13:54] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.379 train_accuracy: 0.289
#
# [2024-05-17 05:14:01] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.370 train_accuracy: 0.328
#
# [2024-05-17 05:14:08] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.356 train_accuracy: 0.353
#
# [2024-05-17 05:14:15] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.341 train_accuracy: 0.373
#
# [2024-05-17 05:14:22] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.326 train_accuracy: 0.396
#
# [2024-05-17 05:14:28] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.314 train_accuracy: 0.415
#
# [2024-05-17 05:14:35] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.303 train_accuracy: 0.423
#
# [2024-05-17 05:14:42] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.292 train_accuracy: 0.439
#
# [2024-05-17 05:14:49] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.282 train_accuracy: 0.457
#
# [2024-05-17 05:14:56] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.274 train_accuracy: 0.461
#
# [2024-05-17 05:15:03] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.265 train_accuracy: 0.478
#
# [2024-05-17 05:15:10] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.256 train_accuracy: 0.487
#
# [2024-05-17 05:15:17] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.249 train_accuracy: 0.509
#
# [2024-05-17 05:15:23] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.238 train_accuracy: 0.520
#
# [2024-05-17 05:15:30] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.229 train_accuracy: 0.521
#
# [2024-05-17 05:15:37] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.222 train_accuracy: 0.532
#
# [2024-05-17 05:15:44] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.219 train_accuracy: 0.533
#
# [2024-05-17 05:15:51] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.208 train_accuracy: 0.546
#
# [2024-05-17 05:15:58] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.207 train_accuracy: 0.543
#
# [2024-05-17 05:16:04] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.201 train_accuracy: 0.550
#
# [2024-05-17 05:16:11] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.194 train_accuracy: 0.561
#
# [2024-05-17 05:16:18] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.192 train_accuracy: 0.564
#
# [2024-05-17 05:16:25] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.182 train_accuracy: 0.573
#
# [2024-05-17 05:16:32] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.180 train_accuracy: 0.571
#
# [2024-05-17 05:16:39] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.178 train_accuracy: 0.573
#
# [2024-05-17 05:16:46] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.170 train_accuracy: 0.590
#
# [2024-05-17 05:16:52] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.167 train_accuracy: 0.593
#
# [2024-05-17 05:16:59] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.162 train_accuracy: 0.603
#
# [2024-05-17 05:17:06] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.155 train_accuracy: 0.607
#
# [2024-05-17 05:17:13] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.156 train_accuracy: 0.604
#
# [2024-05-17 05:17:20] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.152 train_accuracy: 0.609
#
# [2024-05-17 05:17:27] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.141 train_accuracy: 0.620
#
# [2024-05-17 05:17:34] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.140 train_accuracy: 0.619
#
# [2024-05-17 05:17:40] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.140 train_accuracy: 0.615
#
# [2024-05-17 05:17:47] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.139 train_accuracy: 0.620
#
# [2024-05-17 05:17:54] INFO (torcheeg/MainThread)
# [Train] train_loss: 1
INFO (torcheeg/MainThread)
# [Train] train_loss: 1.196 train_accuracy: 0.564
#
# [2024-05-17 05:27:59] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.189 train_accuracy: 0.558
#
# [2024-05-17 05:28:06] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.184 train_accuracy: 0.571
#
# [2024-05-17 05:28:13] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.181 train_accuracy: 0.573
#
# [2024-05-17 05:28:20] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.179 train_accuracy: 0.581
#
# [2024-05-17 05:28:27] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.171 train_accuracy: 0.584
#
# [2024-05-17 05:28:34] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.161 train_accuracy: 0.594
#
# [2024-05-17 05:28:41] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.154 train_accuracy: 0.605
#
# [2024-05-17 05:28:49] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.153 train_accuracy: 0.606
#
# [2024-05-17 05:28:56] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.148 train_accuracy: 0.604
#
# [2024-05-17 05:29:03] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.144 train_accuracy: 0.613
#
# [2024-05-17 05:29:10] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.136 train_accuracy: 0.625
#
# [2024-05-17 05:29:17] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.132 train_accuracy: 0.627
#
# [2024-05-17 05:29:24] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.130 train_accuracy: 0.629
#
# [2024-05-17 05:29:31] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.126 train_accuracy: 0.635
#
# [2024-05-17 05:29:38] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.124 train_accuracy: 0.635
#
# [2024-05-17 05:29:45] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.121 train_accuracy: 0.642
#
# [2024-05-17 05:29:52] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.122 train_accuracy: 0.635
#
# [2024-05-17 05:30:00] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.106 train_accuracy: 0.654
#
# [2024-05-17 05:30:07] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.106 train_accuracy: 0.650
#
# [2024-05-17 05:30:14] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.103 train_accuracy: 0.642
#
# [2024-05-17 05:30:21] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.100 train_accuracy: 0.659
#
# [2024-05-17 05:30:28] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.100 train_accuracy: 0.656
#
# [2024-05-17 05:30:35] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.094 train_accuracy: 0.667
#
# [2024-05-17 05:30:42] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.091 train_accuracy: 0.664
#
# [2024-05-17 05:30:49] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.087 train_accuracy: 0.667
#
# [2024-05-17 05:30:56] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.091 train_accuracy: 0.666
#
# [2024-05-17 05:31:03] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.084 train_accuracy: 0.671
#
# [2024-05-17 05:31:11] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.079 train_accuracy: 0.675
#
# [2024-05-17 05:31:18] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.075 train_accuracy: 0.685
# Testing: |          | 0/? [00:00<?, ?it/s]
# [2024-05-17 05:31:19] INFO (torcheeg/MainThread)
# [Test] test_loss: 1.123 test_accuracy: 0.617
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.6174957156181335     │
# │         test_loss         │    1.1229057312011719     │
# └───────────────────────────┴───────────────────────────┘
# Fold 2 test accuracy:  0.6175
# Training: |          | 0/? [00:00<?, ?it/s]
# [2024-05-17 05:31:30] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.390 train_accuracy: 0.258
#
# [2024-05-17 05:31:37] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.379 train_accuracy: 0.286
#
# [2024-05-17 05:31:45] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.368 train_accuracy: 0.326
#
# [2024-05-17 05:31:52] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.357 train_accuracy: 0.354
#
# [2024-05-17 05:32:00] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.339 train_accuracy: 0.381
#
# [2024-05-17 05:32:07] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.323 train_accuracy: 0.401
#
# [2024-05-17 05:32:14] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.302 train_accuracy: 0.431
#
# [2024-05-17 05:32:22] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.286 train_accuracy: 0.453
#
# [2024-05-17 05:32:29] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.270 train_accuracy: 0.476
#
# [2024-05-17 05:32:36] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.258 train_accuracy: 0.483
#
# [2024-05-17 05:32:44] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.249 train_accuracy: 0.493
#
# [2024-05-17 05:32:51] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.242 train_accuracy: 0.505
#
# [2024-05-17 05:32:59] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.232 train_accuracy: 0.517
#
# [2024-05-17 05:33:06] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.224 train_accuracy: 0.527
#
# [2024-05-17 05:33:13] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.222 train_accuracy: 0.520
#
# [2024-05-17 05:33:21] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.210 train_accuracy: 0.537
#
# [2024-05-17 05:33:28] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.204 train_accuracy: 0.545
#
# [2024-05-17 05:33:35] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.198 train_accuracy: 0.550
#
# [2024-05-17 05:33:43] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.191 train_accuracy: 0.562
#
# [2024-05-17 05:33:50] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.192 train_accuracy: 0.564
#
# [2024-05-17 05:33:58] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.185 train_accuracy: 0.565
#
# [2024-05-17 05:34:05] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.182 train_accuracy: 0.568
#
# [2024-05-17 05:34:12] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.182 train_accuracy: 0.567
#
# [2024-05-17 05:34:20] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.173 train_accuracy: 0.570
#
# [2024-05-17 05:34:27] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.168 train_accuracy: 0.584
#
# [2024-05-17 05:34:34] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.165 train_accuracy: 0.588
#
# [2024-05-17 05:34:42] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.158 train_accuracy: 0.597
#
# [2024-05-17 05:34:49] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.158 train_accuracy: 0.594
#
# [2024-05-17 05:34:57] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.153 train_accuracy: 0.604
#
# [2024-05-17 05:35:04] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.146 train_accuracy: 0.611
#
# [2024-05-17 05:35:11] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.145 train_accuracy: 0.613
#
# [2024-05-17 05:35:19] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.142 train_accuracy: 0.612
#
# [2024-05-17 05:35:26] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.138 train_accuracy: 0.612
#
# [2024-05-17 05:35:33] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.135 train_accuracy: 0.612
#
# [2024-05-17 05:35:41] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.128 train_accuracy: 0.633
#
# [2024-05-17 05:35:48] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.128 train_accuracy: 0.624
#
# [2024-05-17 05:35:55] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.127 train_accuracy: 0.624
#
# [2024-05-17 05:36:03] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.120 train_accuracy: 0.636
#
# [2024-05-17 05:36:10] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.123 train_accuracy: 0.627
#
# [2024-05-17 05:36:17] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.122 train_accuracy: 0.632
#
# [2024-05-17 05:36:25] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.112 train_accuracy: 0.642
#
# [2024-05-17 05:36:32] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.114 train_accuracy: 0.643
#
# [2024-05-17 05:36:39] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.104 train_accuracy: 0.651
#
# [2024-05-17 05:36:47] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.108 train_accuracy: 0.646
#
# [2024-05-17 05:36:54] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.101 train_accuracy: 0.655
#
# [2024-05-17 05:37:02] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.099 train_accuracy: 0.659
#
# [2024-05-17 05:37:09] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.097 train_accuracy: 0.662
#
# [2024-05-17 05:37:16] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.095 train_accuracy: 0.662
#
# [2024-05-17 05:37:24] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.088 train_accuracy: 0.672
#
# [2024-05-17 05:37:31] INFO (torcheeg/MainThread)
# [Train] train_loss: 1.087 train_accuracy: 0.673
# Testing: |          | 0/? [00:00<?, ?it/s]
# [2024-05-17 05:37:32] INFO (torcheeg/MainThread)
# [Test] test_loss: 1.157 test_accuracy: 0.575
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.5745097994804382     │
# │         test_loss         │    1.1566580533981323     │
# └───────────────────────────┴───────────────────────────┘
# Fold 3 test accuracy:  0.5745

# %%
# !mkdir weights

# %%
atc_weights_path = './weights/atc_weights.pt'
torch.save(model.state_dict(), atc_weights_path)
# to load weight:
# model.load_state_dict(torch.load(atc_weights_path))
